# %% [markdown]
# <a href="https://colab.research.google.com/github/e-olang/Computer-Vision/blob/main/Image%20Generation/hugging%20face%20diffusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers -q
# Out:
#      |████████████████████████████████| 94 kB 2.2 MB/s
#      |████████████████████████████████| 4.4 MB 26.0 MB/s
#      |████████████████████████████████| 101 kB 10.6 MB/s
#      |████████████████████████████████| 6.6 MB 47.0 MB/s
#      |████████████████████████████████| 596 kB 63.4 MB/s

# %%
from diffusers import DiffusionPipeline

model_id = "CompVis/ldm-text2im-large-256"

ldm = DiffusionPipeline.from_pretrained(model_id)

prompt = "A painting of a squirrel eating a banana"
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]

'''# save images
for idx, image in enumerate(images):
    image.save(f"squirrel-{idx}.png")'''
# Out:
# Some weights of AutoencoderKL were not initialized from the model checkpoint at /root/.cache/huggingface/diffusers/models--CompVis--ldm-text2im-large-256/snapshots/a1f6625cc7e0f69a350ad16a157263409979f533/vqvae and are newly initialized: ['encoder.down.2.downsample.Conv2d_0.weight', 'encoder.down.2.downsample.Conv2d_0.bias', 'encoder.down.1.downsample.Conv2d_0.bias', 'encoder.down.1.downsample.Conv2d_0.weight', 'encoder.down.0.downsample.Conv2d_0.bias', 'encoder.down.0.downsample.Conv2d_0.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/50 [00:00<?, ?it/s]
# '# save images\nfor idx, image in enumerate(images):\n    image.save(f"squirrel-{idx}.png")'

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F79FA5C7AD0>

# %%
prompt2 = "A cow drinking the moon"
image2 = ldm([prompt2], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]
image2[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F79FA540410>

# %%
image2[0].save("cowmoon.png")

# %%
prompt3 = "a corupt leader"
image3 = ldm([prompt3], num_inference_steps=20, eta=0.3, guidance_scale=6)["sample"]
image3[0]
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F79F92FE950>

# %%
prompt4 = "an arm fracture XRay"
image4 = ldm([prompt4], num_inference_steps=70, eta=0.3, guidance_scale=6)["sample"]
image4[0]
# Out:
#   0%|          | 0/72 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F79F072C990>

# %%
image4[0].save("arm frac.png")
